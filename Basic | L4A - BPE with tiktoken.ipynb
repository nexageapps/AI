# %% [markdown]
# <a href="https://colab.research.google.com/github/nexageapps/AI/blob/main/Basic%20%7C%20L4A%20-%20BPE%20with%20tiktoken.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Author: Karthik Arjun
# LinkedIn: https://www.linkedin.com/in/karthik-arjun-a5b4a258/
# Comment: Beginner Level - Byte Pair Encoding [BPE] with tiktoken
# Reference: https://github.com/openai/tiktoken
# Creation Date: 16/11/2025
# Updated at : 16/11/2025

from importlib.metadata import version
import tiktoken
print("tiktoken version is ", version("tiktoken"))

tokenizer = tiktoken.get_encoding("gpt2")

text = (
    "Hello AI world! <|endoftext|>. Will go for coffee?"
)

integiers = tokenizer.encode(text, allowed_special={"<|endoftext|>"})
print(integiers)
# Out:
# tiktoken version is  0.12.0
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-588013550.py in <cell line: 0>()
#      16 )
#      17
# ---> 18 integiers = tokenzer.encode(text, allowed_special="<|endoftext|>")
#      19 print(integiers)
#      20
#
# /usr/local/lib/python3.12/dist-packages/tiktoken/core.py in encode(self, text, allowed_special, disallowed_special)
#     114             allowed_special = self.special_tokens_set
#     115         if disallowed_special == "all":
# --> 116             disallowed_special = self.special_tokens_set - allowed_special
#     117         if disallowed_special:
#     118             if not isinstance(disallowed_special, frozenset):
#
# TypeError: unsupported operand type(s) for -: 'set' and 'str'
