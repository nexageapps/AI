# %% [markdown]
# # I11 - Model Compression and Optimization
#
# **Author:** Karthik Arjun
# **LinkedIn:** [karthik-arjun-a5b4a258](https://www.linkedin.com/in/karthik-arjun-a5b4a258/)
# **Created:** March 2026
# **Level:** Intermediate
#
# ---
#
# ## Learning Objectives
#
# By the end of this lesson, you will:
# 1. Master pruning techniques for model compression
# 2. Understand quantization (INT8, FP16)
# 3. Learn knowledge distillation
# 4. Deploy models to mobile (TensorFlow Lite)
# 5. Optimize inference performance
#
# ---
#
# ## Prerequisites
#
# - Completed Basic level (B01-B15)
# - Understanding of neural networks
# - Familiarity with model training
#
# ---

# %%
# Import required libraries
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow_model_optimization as tfmot

sns.set_style('whitegrid')
plt.rcParams['figure.figsize'] = (14, 6)

print(f"TensorFlow version: {tf.__version__}")

# %% [markdown]
# ## 1. Why Model Compression?
#
# ### The Problem
#
# **Large models:**
# - High memory requirements
# - Slow inference
# - High energy consumption
# - Can't run on mobile/edge devices
#
# **Example:**
# - GPT-3: 175B parameters, 700GB storage
# - BERT-Large: 340M parameters, 1.3GB storage
# - ResNet-50: 25M parameters, 100MB storage
#
# ### Compression Techniques
#
# 1. **Pruning:** Remove unnecessary weights
# 2. **Quantization:** Reduce precision (FP32 → INT8)
# 3. **Knowledge Distillation:** Train small model from large
# 4. **Low-rank Factorization:** Decompose weight matrices
# 5. **Weight Sharing:** Share weights across layers
