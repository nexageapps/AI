# %% [markdown]
# # I12 - Generative Models
#
# **Author:** Karthik Arjun
# **LinkedIn:** [karthik-arjun-a5b4a258](https://www.linkedin.com/in/karthik-arjun-a5b4a258/)
# **Created:** March 2026
# **Level:** Intermediate
#
# ---
#
# ## Learning Objectives
#
# By the end of this lesson, you will:
# 1. Understand Variational Autoencoders (VAEs)
# 2. Master Generative Adversarial Networks (GANs)
# 3. Learn diffusion models introduction
# 4. Explore applications and use cases
# 5. Compare different generative approaches
#
# ---
#
# ## Prerequisites
#
# - Completed Basic level (B01-B15)
# - Understanding of neural networks
# - Familiarity with CNNs
#
# ---

# %%
# Import required libraries
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style('whitegrid')
plt.rcParams['figure.figsize'] = (14, 6)

print(f"TensorFlow version: {tf.__version__}")

# %% [markdown]
# ## 1. Introduction to Generative Models
#
# ### Discriminative vs Generative
#
# **Discriminative Models:**
# - Learn $P(y|x)$ - probability of label given data
# - Classification, regression
# - Example: "Is this a cat or dog?"
#
# **Generative Models:**
# - Learn $P(x)$ or $P(x|y)$ - probability of data
# - Generate new samples
# - Example: "Create a new cat image"
#
# ### Types of Generative Models
#
# 1. **Variational Autoencoders (VAEs)**
#    - Probabilistic approach
#    - Smooth latent space
#    - Good for interpolation
#
# 2. **Generative Adversarial Networks (GANs)**
#    - Adversarial training
#    - High-quality samples
#    - Harder to train
#
# 3. **Diffusion Models**
#    - Iterative denoising
#    - State-of-the-art quality
#    - Slower generation
#
# 4. **Autoregressive Models**
#    - Sequential generation
#    - Example: GPT, PixelCNN
